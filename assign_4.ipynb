# %%
# ques.1.
import pandas as pd
data = [['akash',20,'aaku@gmail.com',2342324523],['arun',23,'arun@gmail.com',2343423232]]
df = pd.DataFrame(data,columns=['Name','Age','Mail-id','Phn_no'],index=[1,2])
print(df)
# Out:
#     Name  Age         Mail-id      Phn_no
# 1  akash   20  aaku@gmail.com  2342324523
# 2   arun   23  arun@gmail.com  2343423232

# %%
#ques.2.
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')
#a)
df.head(5)
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
#b)
df.head(10)
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
#c)
df['MinTemp'].sum()
# Out:
# 2659.2000000000003

# %%
df['MinTemp'].count()
# Out:
# 366

# %%
df['MinTemp'].mean()
# Out:
# 7.265573770491811

# %%
df['MinTemp'].cumsum()
# Out:
# 0         8.0
# 1        22.0
# 2        35.7
# 3        49.0
# 4        56.6
# 5        62.8
# 6        68.9
# 7        77.2
# 8        86.0
# 9        94.4
# 10      103.5
# 11      112.0
# 12      122.1
# 13      134.2
# 14      144.3
# 15      156.7
# 16      170.5
# 17      182.2
# 18      194.6
# 19      210.2
# 20      225.5
# 21      241.9
# 22      254.7
# 23      266.7
# 24      282.1
# 25      297.7
# 26      311.0
# 27      323.9
# 28      339.0
# 29      352.6
#         ...
# 336    2443.3
# 337    2460.1
# 338    2474.5
# 339    2484.8
# 340    2496.0
# 341    2496.3
# 342    2496.8
# 343    2497.3
# 344    2501.9
# 345    2510.1
# 346    2514.6
# 347    2521.3
# 348    2533.2
# 349    2542.4
# 350    2546.8
# 351    2551.8
# 352    2558.5
# 353    2566.8
# 354    2578.1
# 355    2587.1
# 356    2590.5
# 357    2593.7
# 358    2594.6
# 359    2597.9
# 360    2605.8
# 361    2614.8
# 362    2621.9
# 363    2634.4
# 364    2646.9
# 365    2659.2
# ...

# %%
df['MinTemp'].describe()
# Out:
# count    366.000000
# mean       7.265574
# std        6.025800
# min       -5.300000
# 25%        2.300000
# 50%        7.450000
# 75%       12.500000
# max       20.900000
# Name: MinTemp, dtype: float64

# %%
df['MinTemp'].min()
# Out:
# -5.3

# %%
df['MinTemp'].max()
# Out:
# 20.9

# %%
df['MinTemp'].var()
# Out:
# 36.3102636424882

# %%
df['MinTemp'].median()
# Out:
# 7.45

# %%
#d)
df.tail(5)
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 361         NNW           76.0        SSE      ...               15
# 362           N           48.0        NNW      ...               22
# 363         ESE           43.0        ENE      ...               47
# 364          NW           46.0        SSW      ...               39
# 365          NW           78.0         NW      ...               13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
#e)
df.iloc[:,1]
# Out:
# 0      Canberra
# 1      Canberra
# 2      Canberra
# 3      Canberra
# 4      Canberra
# 5      Canberra
# 6      Canberra
# 7      Canberra
# 8      Canberra
# 9      Canberra
# 10     Canberra
# 11     Canberra
# 12     Canberra
# 13     Canberra
# 14     Canberra
# 15     Canberra
# 16     Canberra
# 17     Canberra
# 18     Canberra
# 19     Canberra
# 20     Canberra
# 21     Canberra
# 22     Canberra
# 23     Canberra
# 24     Canberra
# 25     Canberra
# 26     Canberra
# 27     Canberra
# 28     Canberra
# 29     Canberra
#          ...
# 336    Canberra
# 337    Canberra
# 338    Canberra
# 339    Canberra
# 340    Canberra
# 341    Canberra
# 342    Canberra
# 343    Canberra
# 344    Canberra
# 345    Canberra
# 346    Canberra
# 347    Canberra
# 348    Canberra
# 349    Canberra
# 350    Canberra
# 351    Canberra
# 352    Canberra
# 353    Canberra
# 354    Canberra
# 355    Canberra
# 356    Canberra
# 357    Canberra
# 358    Canberra
# 359    Canberra
# ...
