# %%
import pandas as pd
df= pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
head=df.head()
head
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import random
# %matplotlib inline

# %%
maxtemp = df['MaxTemp']
eva = df['Evaporation']
plt.plot(maxtemp,eva)
plt.xlabel('temp')
plt.ylabel('eva.')
plt.title('plot')
plt.show()

# %%
plt.plot(rainhead,minhead)
plt.xlabel('rain')
plt.ylabel('windsped')
plt.title('plot')
plt.show()

# %%
rain= df['Rainfall']
wind= df['WindGustSpeed']
plt.scatter(rain,wind,edgecolors= 'r')
plt.xlabel('rain')
plt.ylabel('windspeed')
plt.title('plot')
plt.show()

# %%
rain= df['Rainfall']
wind= df['WindGustSpeed']
plt.plot(rain,wind,'--')
plt.show()

# %%
maxtemp = df['MaxTemp']
mintemp = df['MinTemp']
ax = sns.stripplot(maxtemp,mintemp)
plt.show()

# %%
rainfall = df['Rainfall']
rainhead= rainfall.head(10)
rainhead
# Out:
# 0     0.0
# 1     3.6
# 2     3.6
# 3    39.8
# 4     2.8
# 5     0.0
# 6     0.2
# 7     0.0
# 8     0.0
# 9    16.2
# Name: Rainfall, dtype: float64

# %%
mintemp = df['MinTemp']
minhead = mintemp.head(10)
minhead
# Out:
# 0     8.0
# 1    14.0
# 2    13.7
# 3    13.3
# 4     7.6
# 5     6.2
# 6     6.1
# 7     8.3
# 8     8.8
# 9     8.4
# Name: MinTemp, dtype: float64

# %%
ax = sns.stripplot(rainhead,minhead)
#ax.set(xlable='rain')
#ax.set(ylable='mintemp')
#plt.title('temp')
plt.show()

# %%
fig= plt.figure()
ax= fig.add_subplot(1,1,1)
ax.hist(minhead)
plt.title('Minhead')
plt.show()

# %%
fig= plt.figure()
ax= fig.add_subplot(1,1,1)
ax.boxplot(rainhead)
plt.title('Rainfall')
plt.show()

# %%
sns.violinplot(rainhead,minhead)
sns.despine()

# %%
var= df.groupby([rainhead,minhead]).Rainfall.sum()
var.unstack().plot(kind='bar',stacked=True,color=['red','blue']
                  )

# %%
ax= plt.subplot2grid((2,2),(0,0))
ax.plot(rainhead)
ax1= plt.subplot2grid((2,2),(0,1))
ax1.plot(minhead)
plt.show()
